# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\singapure\ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")

# %%
df2=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\singapure\ResaleFlatPricesBasedonApprovalDate19901999.csv")

# %%
df3=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\singapure\ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv").drop(columns='remaining_lease')
# df3=df3_.drop(columns='remaining_lease')

# %%
df4=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\singapure\ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv").drop(columns='remaining_lease')

# %%
df5=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\singapure\ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")

# %%
df1.shape,df2.shape,df3.shape,df4.shape,df5.shape
# Out:
# ((369651, 10), (287196, 10), (37153, 10), (168154, 10), (52203, 10))

# %%
df1.shape[0]+df2.shape[0]+df3.shape[0]+df4.shape[0]+df5.shape[0]
# Out:
# 914357

# %%
df1.head(2)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price
# 0            69.0   Improved                 1986      147000.0
# 1            61.0   Improved                 1986      144000.0

# %%
df2.head(2)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price
# 0            31.0   IMPROVED                 1977          9000
# 1            31.0   IMPROVED                 1977          6000

# %%
df3.head(2)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            60.0        Improved                 1986      255000.0
# 1            68.0  New Generation                 1981      275000.0

# %%
df4.head(2)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            44.0        Improved                 1979      232000.0
# 1            67.0  New Generation                 1978      250000.0

# %%
df5.head(2)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172  ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510  ANG MO KIO AVE 8     01 TO 05
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price
# 0            45.0   Improved                 1986      250000.0
# 1            44.0   Improved                 1980      265000.0

# %%
df=pd.concat([df1,df2,df3,df4,df5],ignore_index=True)
df.shape
# Out:
# (914357, 10)

# %%
df.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3  2000-01  ANG MO KIO    3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4  2000-01  ANG MO KIO    3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0
# 3            73.0  New Generation                 1976      167000.0
# 4            67.0  New Generation                 1976      163000.0

# %%
df[df.duplicated()]
# Out:
#           month        town flat_type block        street_name storey_range  \
# 22      2000-01  ANG MO KIO    3 ROOM   443  ANG MO KIO AVE 10     07 TO 09
# 176     2000-01       BEDOK    3 ROOM    32      CHAI CHEE AVE     13 TO 15
# 285     2000-01       BEDOK    4 ROOM   421       BEDOK NTH RD     13 TO 15
# 868     2000-01    CLEMENTI    3 ROOM   518      WEST COAST RD     10 TO 12
# 2327    2000-01      YISHUN    4 ROOM   249       YISHUN AVE 9     10 TO 12
# ...         ...         ...       ...   ...                ...          ...
# 906912  2014-07    SENGKANG    4 ROOM  272D      SENGKANG CTRL     01 TO 03
# 907742  2014-08    CLEMENTI    4 ROOM   347     CLEMENTI AVE 5     10 TO 12
# 911772  2014-11       BEDOK    3 ROOM   529     BEDOK NTH ST 3     13 TO 15
# 912651  2014-11    SENGKANG    4 ROOM  271C      SENGKANG CTRL     04 TO 06
# 914257  2014-12   WOODLANDS    5 ROOM   664  WOODLANDS RING RD     01 TO 03
#
# ...

# %%
df.drop_duplicates(keep="first",inplace=True)

# %%
# df.to_csv('new_singapur.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912399 entries, 0 to 914356
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                912399 non-null  object
#  1   town                 912399 non-null  object
#  2   flat_type            912399 non-null  object
#  3   block                912399 non-null  object
#  4   street_name          912399 non-null  object
#  5   storey_range         912399 non-null  object
#  6   floor_area_sqm       912399 non-null  float64
#  7   flat_model           912399 non-null  object
#  8   lease_commence_date  912399 non-null  int64
#  9   resale_price         912399 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 76.6+ MB

# %%
df.head(10)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3  2000-01  ANG MO KIO    3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4  2000-01  ANG MO KIO    3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# 5  2000-01  ANG MO KIO    3 ROOM   320  ANG MO KIO AVE 1     04 TO 06
# 6  2000-01  ANG MO KIO    3 ROOM   320  ANG MO KIO AVE 1     07 TO 09
# 7  2000-01  ANG MO KIO    3 ROOM   330  ANG MO KIO AVE 1     07 TO 09
# 8  2000-01  ANG MO KIO    3 ROOM   330  ANG MO KIO AVE 1     04 TO 06
# 9  2000-01  ANG MO KIO    3 ROOM   332  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# ...

# %%
# for i in df.columns:
    
#     print(df[i].value_counts())
#     print( i,"##################################################################")
